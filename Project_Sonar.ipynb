# %%
import pandas as pd

# %%
df=pd.read_csv('sonar_dataset.csv')

# %%
df.head()
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6  column_7  \
# 0    0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539
# 1    0.0453    0.0523    0.0843    0.0689    0.1183    0.2583    0.2156
# 2    0.0262    0.0582    0.1099    0.1083    0.0974    0.2280    0.2431
# 3    0.0100    0.0171    0.0623    0.0205    0.0205    0.0368    0.1098
# 4    0.0762    0.0666    0.0481    0.0394    0.0590    0.0649    0.1209
#
#    column_8  column_9  column_10  ...  column_52  column_53  column_54  \
# 0    0.1601    0.3109     0.2111  ...     0.0027     0.0065     0.0159
# 1    0.3481    0.3337     0.2872  ...     0.0084     0.0089     0.0048
# 2    0.3771    0.5598     0.6194  ...     0.0232     0.0166     0.0095
# 3    0.1276    0.0598     0.1264  ...     0.0121     0.0036     0.0150
# 4    0.2467    0.3564     0.4459  ...     0.0031     0.0054     0.0105
#
#    column_55  column_56  column_57  column_58  column_59  column_60  column_61
# 0     0.0072     0.0167     0.0180     0.0084     0.0090     0.0032          R
# 1     0.0094     0.0191     0.0140     0.0049     0.0052     0.0044          R
# 2     0.0180     0.0244     0.0316     0.0164     0.0095     0.0078          R
# 3     0.0085     0.0073     0.0050     0.0044     0.0040     0.0117          R
# 4     0.0110     0.0015     0.0072     0.0048     0.0107     0.0094          R
#
# [5 rows x 61 columns]

# %%
df.tail()
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6  column_7  \
# 203    0.0187    0.0346    0.0168    0.0177    0.0393    0.1630    0.2028
# 204    0.0323    0.0101    0.0298    0.0564    0.0760    0.0958    0.0990
# 205    0.0522    0.0437    0.0180    0.0292    0.0351    0.1171    0.1257
# 206    0.0303    0.0353    0.0490    0.0608    0.0167    0.1354    0.1465
# 207    0.0260    0.0363    0.0136    0.0272    0.0214    0.0338    0.0655
#
#      column_8  column_9  column_10  ...  column_52  column_53  column_54  \
# 203    0.1694    0.2328     0.2684  ...     0.0116     0.0098     0.0199
# 204    0.1018    0.1030     0.2154  ...     0.0061     0.0093     0.0135
# 205    0.1178    0.1258     0.2529  ...     0.0160     0.0029     0.0051
# 206    0.1123    0.1945     0.2354  ...     0.0086     0.0046     0.0126
# 207    0.1400    0.1843     0.2354  ...     0.0146     0.0129     0.0047
#
#      column_55  column_56  column_57  column_58  column_59  column_60  \
# 203     0.0033     0.0101     0.0065     0.0115     0.0193     0.0157
# 204     0.0063     0.0063     0.0034     0.0032     0.0062     0.0067
# 205     0.0062     0.0089     0.0140     0.0138     0.0077     0.0031
# 206     0.0036     0.0035     0.0034     0.0079     0.0036     0.0048
# 207     0.0039     0.0061     0.0040     0.0036     0.0061     0.0115
#
#      column_61
# 203          M
# 204          M
# 205          M
# 206          M
# 207          M
#
# [5 rows x 61 columns]

# %%
df.shape
# Out:
# (208, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   column_1   208 non-null    float64
#  1   column_2   208 non-null    float64
#  2   column_3   208 non-null    float64
#  3   column_4   208 non-null    float64
#  4   column_5   208 non-null    float64
#  5   column_6   208 non-null    float64
#  6   column_7   208 non-null    float64
#  7   column_8   208 non-null    float64
#  8   column_9   208 non-null    float64
#  9   column_10  208 non-null    float64
#  10  column_11  208 non-null    float64
#  11  column_12  208 non-null    float64
#  12  column_13  208 non-null    float64
#  13  column_14  208 non-null    float64
#  14  column_15  208 non-null    float64
#  15  column_16  208 non-null    float64
#  16  column_17  208 non-null    float64
#  17  column_18  208 non-null    float64
#  18  column_19  208 non-null    float64
#  19  column_20  208 non-null    float64
#  20  column_21  208 non-null    float64
#  21  column_22  208 non-null    float64
#  22  column_23  208 non-null    float64
#  23  column_24  208 non-null    float64
#  24  column_25  208 non-null    float64
#  25  column_26  208 non-null    float64
#  26  column_27  208 non-null    float64
#  27  column_28  208 non-null    float64
#  28  column_29  208 non-null    float64
#  29  column_30  208 non-null    float64
#  30  column_31  208 non-null    float64
#  31  column_32  208 non-null    float64
#  32  column_33  208 non-null    float64
#  33  column_34  208 non-null    float64
#  34  column_35  208 non-null    float64
#  35  column_36  208 non-null    float64
#  36  column_37  208 non-null    float64
#  37  column_38  208 non-null    float64
#  38  column_39  208 non-null    float64
#  39  column_40  208 non-null    float64
#  40  column_41  208 non-null    float64
#  41  column_42  208 non-null    float64
#  42  column_43  208 non-null    float64
#  43  column_44  208 non-null    float64
#  44  column_45  208 non-null    float64
#  45  column_46  208 non-null    float64
#  46  column_47  208 non-null    float64
#  47  column_48  208 non-null    float64
#  48  column_49  208 non-null    float64
#  49  column_50  208 non-null    float64
#  50  column_51  208 non-null    float64
#  51  column_52  208 non-null    float64
#  52  column_53  208 non-null    float64
#  53  column_54  208 non-null    float64
#  54  column_55  208 non-null    float64
#  55  column_56  208 non-null    float64
#  56  column_57  208 non-null    float64
#  57  column_58  208 non-null    float64
#  58  column_59  208 non-null    float64
#  59  column_60  208 non-null    float64
#  60  column_61  208 non-null    object
# dtypes: float64(60), object(1)
# memory usage: 99.2+ KB

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
df.isnull()
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6  column_7  \
# 0       False     False     False     False     False     False     False
# 1       False     False     False     False     False     False     False
# 2       False     False     False     False     False     False     False
# 3       False     False     False     False     False     False     False
# 4       False     False     False     False     False     False     False
# ..        ...       ...       ...       ...       ...       ...       ...
# 203     False     False     False     False     False     False     False
# 204     False     False     False     False     False     False     False
# 205     False     False     False     False     False     False     False
# 206     False     False     False     False     False     False     False
# 207     False     False     False     False     False     False     False
#
#      column_8  column_9  column_10  ...  column_52  column_53  column_54  \
# 0       False     False      False  ...      False      False      False
# 1       False     False      False  ...      False      False      False
# 2       False     False      False  ...      False      False      False
# 3       False     False      False  ...      False      False      False
# 4       False     False      False  ...      False      False      False
# ..        ...       ...        ...  ...        ...        ...        ...
# 203     False     False      False  ...      False      False      False
# 204     False     False      False  ...      False      False      False
# 205     False     False      False  ...      False      False      False
# 206     False     False      False  ...      False      False      False
# 207     False     False      False  ...      False      False      False
#
#      column_55  column_56  column_57  column_58  column_59  column_60  \
# 0        False      False      False      False      False      False
# 1        False      False      False      False      False      False
# 2        False      False      False      False      False      False
# 3        False      False      False      False      False      False
# 4        False      False      False      False      False      False
# ..         ...        ...        ...        ...        ...        ...
# 203      False      False      False      False      False      False
# 204      False      False      False      False      False      False
# 205      False      False      False      False      False      False
# 206      False      False      False      False      False      False
# 207      False      False      False      False      False      False
#
#      column_61
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 203      False
# 204      False
# 205      False
# 206      False
# 207      False
#
# [208 rows x 61 columns]

# %%
df.isnull().sum()
# Out:
# column_1     0
# column_2     0
# column_3     0
# column_4     0
# column_5     0
#             ..
# column_57    0
# column_58    0
# column_59    0
# column_60    0
# column_61    0
# Length: 61, dtype: int64

# %%
sbn.heatmap(df.isnull())

# %%
df.describe()
# Out:
#          column_1    column_2    column_3    column_4    column_5    column_6  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#          column_7    column_8    column_9   column_10  ...   column_51  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# std      0.061788    0.085152    0.118387    0.134416  ...    0.012008
# min      0.003300    0.005500    0.007500    0.011300  ...    0.000000
# 25%      0.080900    0.080425    0.097025    0.111275  ...    0.008425
# 50%      0.106950    0.112100    0.152250    0.182400  ...    0.013900
# 75%      0.154000    0.169600    0.233425    0.268700  ...    0.020825
# max      0.372900    0.459000    0.682800    0.710600  ...    0.100400
#
#         column_52   column_53   column_54   column_55   column_56   column_57  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.013420    0.010709    0.010941    0.009290    0.008222    0.007820
# std      0.009634    0.007060    0.007301    0.007088    0.005736    0.005785
# min      0.000800    0.000500    0.001000    0.000600    0.000400    0.000300
# 25%      0.007275    0.005075    0.005375    0.004150    0.004400    0.003700
# 50%      0.011400    0.009550    0.009300    0.007500    0.006850    0.005950
# 75%      0.016725    0.014900    0.014500    0.012100    0.010575    0.010425
# max      0.070900    0.039000    0.035200    0.044700    0.039400    0.035500
#
#         column_58   column_59   column_60
# count  208.000000  208.000000  208.000000
# mean     0.007949    0.007941    0.006507
# std      0.006470    0.006181    0.005031
# min      0.000300    0.000100    0.000600
# 25%      0.003600    0.003675    0.003100
# 50%      0.005800    0.006400    0.005300
# 75%      0.010350    0.010325    0.008525
# max      0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
df=pd.DataFrame(data=df)

# %%
df
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6  column_7  \
# 0      0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539
# 1      0.0453    0.0523    0.0843    0.0689    0.1183    0.2583    0.2156
# 2      0.0262    0.0582    0.1099    0.1083    0.0974    0.2280    0.2431
# 3      0.0100    0.0171    0.0623    0.0205    0.0205    0.0368    0.1098
# 4      0.0762    0.0666    0.0481    0.0394    0.0590    0.0649    0.1209
# ..        ...       ...       ...       ...       ...       ...       ...
# 203    0.0187    0.0346    0.0168    0.0177    0.0393    0.1630    0.2028
# 204    0.0323    0.0101    0.0298    0.0564    0.0760    0.0958    0.0990
# 205    0.0522    0.0437    0.0180    0.0292    0.0351    0.1171    0.1257
# 206    0.0303    0.0353    0.0490    0.0608    0.0167    0.1354    0.1465
# 207    0.0260    0.0363    0.0136    0.0272    0.0214    0.0338    0.0655
#
#      column_8  column_9  column_10  ...  column_52  column_53  column_54  \
# 0      0.1601    0.3109     0.2111  ...     0.0027     0.0065     0.0159
# 1      0.3481    0.3337     0.2872  ...     0.0084     0.0089     0.0048
# 2      0.3771    0.5598     0.6194  ...     0.0232     0.0166     0.0095
# 3      0.1276    0.0598     0.1264  ...     0.0121     0.0036     0.0150
# 4      0.2467    0.3564     0.4459  ...     0.0031     0.0054     0.0105
# ..        ...       ...        ...  ...        ...        ...        ...
# 203    0.1694    0.2328     0.2684  ...     0.0116     0.0098     0.0199
# 204    0.1018    0.1030     0.2154  ...     0.0061     0.0093     0.0135
# 205    0.1178    0.1258     0.2529  ...     0.0160     0.0029     0.0051
# 206    0.1123    0.1945     0.2354  ...     0.0086     0.0046     0.0126
# 207    0.1400    0.1843     0.2354  ...     0.0146     0.0129     0.0047
#
#      column_55  column_56  column_57  column_58  column_59  column_60  \
# 0       0.0072     0.0167     0.0180     0.0084     0.0090     0.0032
# 1       0.0094     0.0191     0.0140     0.0049     0.0052     0.0044
# 2       0.0180     0.0244     0.0316     0.0164     0.0095     0.0078
# 3       0.0085     0.0073     0.0050     0.0044     0.0040     0.0117
# 4       0.0110     0.0015     0.0072     0.0048     0.0107     0.0094
# ..         ...        ...        ...        ...        ...        ...
# 203     0.0033     0.0101     0.0065     0.0115     0.0193     0.0157
# 204     0.0063     0.0063     0.0034     0.0032     0.0062     0.0067
# 205     0.0062     0.0089     0.0140     0.0138     0.0077     0.0031
# 206     0.0036     0.0035     0.0034     0.0079     0.0036     0.0048
# 207     0.0039     0.0061     0.0040     0.0036     0.0061     0.0115
#
#      column_61
# 0            R
# 1            R
# 2            R
# 3            R
# 4            R
# ..         ...
# 203          M
# 204          M
# 205          M
# 206          M
# 207          M
#
# [208 rows x 61 columns]

# %%
sbn.heatmap(df.corr(),annot=True)

# %%
x=df.iloc[:,:-1]
x.head()
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6  column_7  \
# 0    0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539
# 1    0.0453    0.0523    0.0843    0.0689    0.1183    0.2583    0.2156
# 2    0.0262    0.0582    0.1099    0.1083    0.0974    0.2280    0.2431
# 3    0.0100    0.0171    0.0623    0.0205    0.0205    0.0368    0.1098
# 4    0.0762    0.0666    0.0481    0.0394    0.0590    0.0649    0.1209
#
#    column_8  column_9  column_10  ...  column_51  column_52  column_53  \
# 0    0.1601    0.3109     0.2111  ...     0.0232     0.0027     0.0065
# 1    0.3481    0.3337     0.2872  ...     0.0125     0.0084     0.0089
# 2    0.3771    0.5598     0.6194  ...     0.0033     0.0232     0.0166
# 3    0.1276    0.0598     0.1264  ...     0.0241     0.0121     0.0036
# 4    0.2467    0.3564     0.4459  ...     0.0156     0.0031     0.0054
#
#    column_54  column_55  column_56  column_57  column_58  column_59  column_60
# 0     0.0159     0.0072     0.0167     0.0180     0.0084     0.0090     0.0032
# 1     0.0048     0.0094     0.0191     0.0140     0.0049     0.0052     0.0044
# 2     0.0095     0.0180     0.0244     0.0316     0.0164     0.0095     0.0078
# 3     0.0150     0.0085     0.0073     0.0050     0.0044     0.0040     0.0117
# 4     0.0105     0.0110     0.0015     0.0072     0.0048     0.0107     0.0094
#
# [5 rows x 60 columns]

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca=PCA(6)
x=pca.fit_transform(x)
x=pd.DataFrame(data=x)

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    R
# 1    R
# 2    R
# 3    R
# 4    R
# Name: column_61, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=45)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
x_test.head()
# Out:
# (166, 6)
# (166,)
# (42, 6)
# (42,)
#             0         1         2         3         4         5
# 179 -0.595189 -1.408360  1.227269  0.975194  1.322843  0.413660
# 82  -1.769726  2.624711  1.297495  0.253483 -0.764057 -2.681256
# 113 -1.617698  3.232885 -1.545361 -0.794036 -2.143226  0.146471
# 195 -3.083024 -1.231108  3.814015 -0.088182  0.102304 -0.373150
# 73  -3.065324 -3.174952 -0.621513 -1.374443 -0.218487 -0.036788

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,f1_score,precision_score

# %%
def model(a):
    ml=a
    ml.fit(x_train,y_train)
    train=ml.score(x_train,y_train)
    pre=ml.predict(x_test)
    a= accuracy_score(y_test,pre)
    cm=sbn.heatmap(confusion_matrix(y_test,pre),annot=True)
    cr=classification_report(y_test,pre)
    f1=f1_score(y_test,pre)
    ps=precision_score(y_test,pre)
    return print('Traning_score = ',train ,'\n\nAccuracy_score = ',a,'\n\nClassification_Report =\n',cr,'\n\nF1_score = ',f1,'\n\nPrecision_score = ',ps,'\n\nConfusion_Matrix',cm)

# %%
from sklearn.linear_model import LogisticRegression
model(LogisticRegression())
# Out:
# Traning_score =  0.7590361445783133
#
# Accuracy_score =  0.7619047619047619
#
# Classification_Report =
#                precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76        19
#            1       0.84      0.70      0.76        23
#
#     accuracy                           0.76        42
#    macro avg       0.77      0.77      0.76        42
# weighted avg       0.78      0.76      0.76        42
#
#
# F1_score =  0.761904761904762
#
# Precision_score =  0.8421052631578947
#
# Confusion_Matrix AxesSubplot(0.125,0.125;0.62x0.755)

# %%
from sklearn.naive_bayes import GaussianNB
model(GaussianNB())
# Out:
# Traning_score =  0.7710843373493976
#
# Accuracy_score =  0.8333333333333334
#
# Classification_Report =
#                precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81        19
#            1       0.83      0.87      0.85        23
#
#     accuracy                           0.83        42
#    macro avg       0.83      0.83      0.83        42
# weighted avg       0.83      0.83      0.83        42
#
#
# F1_score =  0.851063829787234
#
# Precision_score =  0.8333333333333334
#
# Confusion_Matrix AxesSubplot(0.125,0.125;0.62x0.755)

# %%
from sklearn.svm import SVC
model(SVC())
# Out:
# Traning_score =  0.8855421686746988
#
# Accuracy_score =  0.8095238095238095
#
# Classification_Report =
#                precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80        19
#            1       0.86      0.78      0.82        23
#
#     accuracy                           0.81        42
#    macro avg       0.81      0.81      0.81        42
# weighted avg       0.81      0.81      0.81        42
#
#
# F1_score =  0.8181818181818182
#
# Precision_score =  0.8571428571428571
#
# Confusion_Matrix AxesSubplot(0.125,0.125;0.62x0.755)

# %%
from sklearn.neighbors import KNeighborsClassifier
model(KNeighborsClassifier())
# Out:
# Traning_score =  0.8433734939759037
#
# Accuracy_score =  0.8809523809523809
#
# Classification_Report =
#                precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        19
#            1       0.91      0.87      0.89        23
#
#     accuracy                           0.88        42
#    macro avg       0.88      0.88      0.88        42
# weighted avg       0.88      0.88      0.88        42
#
#
# F1_score =  0.888888888888889
#
# Precision_score =  0.9090909090909091
#
# Confusion_Matrix AxesSubplot(0.125,0.125;0.62x0.755)

# %%
from sklearn.tree import DecisionTreeClassifier
model(DecisionTreeClassifier())
# Out:
# Traning_score =  1.0
#
# Accuracy_score =  0.6904761904761905
#
# Classification_Report =
#                precision    recall  f1-score   support
#
#            0       0.62      0.79      0.70        19
#            1       0.78      0.61      0.68        23
#
#     accuracy                           0.69        42
#    macro avg       0.70      0.70      0.69        42
# weighted avg       0.71      0.69      0.69        42
#
#
# F1_score =  0.6829268292682927
#
# Precision_score =  0.7777777777777778
#
# Confusion_Matrix AxesSubplot(0.125,0.125;0.62x0.755)

# %%
model=[LogisticRegression(),
       GaussianNB(),
       SVC(),
       KNeighborsClassifier(),
       DecisionTreeClassifier()]

# %%
F1_score=[]
Accuracy_score=[]
models=['LogisticRegression',
       'GaussianNB',
       'SVC',
       'KNeighborsClassifier',
       'DecisionTreeClassifier']
for i in model:
    ml=i
    ml.fit(x_train,y_train)
    pre=ml.predict(x_test)
    F1_score.append(f1_score(y_test,pre))
    Accuracy_score.append(accuracy_score(y_test,pre))

# %%
result=pd.DataFrame({'Model':models,'F1_score':F1_score,'Accuracy_score':Accuracy_score})
result
# Out:
#                     Model  F1_score  Accuracy_score
# 0      LogisticRegression  0.761905        0.761905
# 1              GaussianNB  0.851064        0.833333
# 2                     SVC  0.818182        0.809524
# 3    KNeighborsClassifier  0.888889        0.880952
# 4  DecisionTreeClassifier  0.650000        0.666667

# %% [markdown]
# I select KNeighbore Classifier as final model

# %%
from sklearn.externals import joblib
joblib.dump(KNeighborsClassifier,'Project_Sonar.obj')
# Out:
# C:\Users\Amit\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['Project_Sonar.obj']

# %%
KNC=joblib.load('Project_Sonar.obj')
KNC.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-6938f36afe96> in <module>
#       1 KNC=joblib.load('Project_Sonar.obj')
# ----> 2 KNC.predict(x_test)
#
# TypeError: predict() missing 1 required positional argument: 'X'
